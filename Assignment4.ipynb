# %%
my__dict = {"First_name": "Faiq", "Last_name": "Mahmood", "Age": 18, "City": "Karachi"}

print(my__dict.items())

my__dict["Qualification"] = "Intermediate"

my__dict.update({"Qualification": "Higher education"})

del my__dict["Qualification"]

print(my__dict)
# Out:
# dict_items([('First_name', 'Faiq'), ('Last_name', 'Mahmood'), ('Age', 18), ('City', 'Karachi')])
# {'First_name': 'Faiq', 'Last_name': 'Mahmood', 'Age': 18, 'City': 'Karachi'}

# %%
cities = {"Karachi": {"Country": "Pakistan", "Population": "14.91 million", "Fact": "Sea Harbour"},
          "Islamabad": {"Country": "Pakistan", "Population": "1.015 million", "Fact": "Capital"},
          "Lahore": {"Country": "Pakistan", "Population": "11.13 million ", "Fact": "Lahore Lahore hai"}
          }

print(cities)
# Out:
# {'Karachi': {'Country': 'Pakistan', 'Population': '14.91 million', 'Fact': 'Sea Harbour'}, 'Islamabad': {'Country': 'Pakistan', 'Population': '1.015 million', 'Fact': 'Capital'}, 'Lahore': {'Country': 'Pakistan', 'Population': '11.13 million ', 'Fact': 'Lahore Lahore hai'}}

# %%
age = int(input("Enter the age: "))
if age < 3:
    print('Your Ticket Is Free')
elif 3 <= age <= 12:
    print('The Cost For Your Ticket Is $10')
elif age > 12:
    print('The Cost For Your Ticket Is $15')
# Out:
# Enter the age: 2
# Your Ticket Is Free

# %%
def favorite_function(title):
    print("One of my favorite books is:", title)


my_title = input("Enter the title of the book: ")

favorite_function(my_title)
# Out:
# Enter the title of the book: Alice
# One of my favorite books is: Alice

# %%
import random

random_number = random.randint(1, 30)

for i in range(3):
    user_guess = int(input("Enter to guess the number: "))

    if user_guess > random_number:
        print("Your number was greater than the number generated by me.")
    elif user_guess < random_number:
        print("Your number was lesser than the number generated by me.")
    elif user_guess == random_number:
        print("Great!! You guessed right number.")
# Out:
# Enter to guess the number: 14
# Your number was lesser than the number generated by me.
# Enter to guess the number: 13
# Your number was lesser than the number generated by me.
# Enter to guess the number: 20
# Your number was lesser than the number generated by me.
